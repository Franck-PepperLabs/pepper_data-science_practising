# %% [markdown]
# # Main config

# %% [markdown]
# ## Project folder organisation

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

gdrive = '/content/drive/My Drive/'
colab_base = gdrive + 'Colab Notebooks/'
working_dir = colab_base + 'Franck | Plot training'

# bootstrap
from google.colab import drive
drive.mount('/content/drive')

# %cd {working_dir}
# %mkdir 'img'
# !ls -la
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks/Franck | Plot training
# mkdir: cannot create directory ‘img’: File exists
# total 1291
# drwx------ 2 root root    4096 Jul 23 18:12  img
# -rw------- 1 root root 1317568 Jul 31 20:28 'Plot training.ipynb'

# %% [markdown]
# ## My style

# %%
fig_shape = (16, 9)

# Voir : https://stackoverflow.com/questions/28617263/matplotlib-set-width-or-height-of-figure-without-changing-aspect-ratio
# Voir : https://stackoverflow.com/questions/332289/how-do-i-change-the-size-of-figures-drawn-with-matplotlib

# Voir sutout! : https://matplotlib.org/stable/tutorials/introductory/customizing.html
my_jupyter_rcp = {
    
}

# %% [markdown]
# # Matplotlib
#
# https://matplotlib.org/stable/users/index.html

# %% [markdown]
# ## [Getting Started](https://matplotlib.org/stable/users/getting_started/index.html)
#
# 29/07 7:00

# %%
# minimal example plot
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 200)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %% [markdown]
# ## [Utilisation de base](https://matplotlib.org/stable/tutorials/introductory/usage.html)

# %% [markdown]
# ### Un exemple simple

# %%
fig, ax = plt.subplots()              # Create a figure containing a single axes
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])   # Plot some data on the axes

# %% [markdown]
# ### Parties d'une figure
#
# <img src='https://matplotlib.org/stable/_images/anatomy.png' alt='anatomy' height='400' width='400'/>

# %% [markdown]
# #### Figure

# %%
fig = plt.figure()            # empty figure with no Axes
fig, ax = plt.subplots()      # a figure with a single Axes
fig, ax = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes

# %% [markdown]
# #### Axes, Axis, Artist

# %%
ax.set_title('My Title')
ax.set_ylabel('My Ylabel')
ax.plot()
plt.show()

# %% [markdown]
# ## Types de fonctions de traçage
#
# Attention aux array-like qui ne sont pas des ndarrays : résultats imprévisibles.
#
# Les transformer préalablement avec np.asarray().

# %%
b = np.matrix([[1, 2], [3, 4]])
b_ar = np.asarray(b)

# %%
import time
# production des données
np.random.seed(int(time.time()))
data = {
    'a': np.arange(50),
    'c': np.random.randint(0, 50, 50),
    'd': np.random.randn(50)
}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

# affichage
fig, ax = plt.subplots(figsize=(10, 5.4)) #, layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('Entrée a')
ax.set_ylabel('Entrée b')
# Out:
# Text(0, 0.5, 'Entrée b')

# %% [markdown]
# ## Coding style

# %% [markdown]
# ### OO Style

# %%
import math

x = np.linspace(0, 2, 100)  # Sample data.

# Note that even in the OO-style, we use `.pyplot.figure` to create the Figure.
fig, ax = plt.subplots(figsize=(16, 9)) #, layout='constrained')
ax.plot(x, np.log(x) , label='ln')  # Plot some data on the axes.
ax.plot(x, x**0.5, label='square root')  # Plot some data on the axes.
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.plot(x, np.exp(x) / np.exp(1), label='exp')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()  # Add a legend.
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys

# %% [markdown]
# ### PLT Style

# %%
import math

x = np.linspace(0, 2, 100)  # Sample data.

# Note that even in the OO-style, we use `.pyplot.figure` to create the Figure.
plt.figure(figsize=(16, 9)) #, layout='constrained')
plt.plot(x, np.log(x) , label='ln')  # Plot some data on the axes.
plt.plot(x, x**0.5, label='square root')  # Plot some data on the axes.
plt.plot(x, x, label='linear')  # Plot some data on the axes.
plt.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
plt.plot(x, x**3, label='cubic')  # ... and some more.
plt.plot(x, np.exp(x) / np.exp(1), label='exp')  # ... and some more.
plt.xlabel('x label')  # Add an x-label to the axes.
plt.ylabel('y label')  # Add a y-label to the axes.
plt.title("Simple Plot")  # Add a title to the axes.
plt.legend()  # Add a legend.
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys

# %% [markdown]
# ## Faire une fonction utilitaire
#
# Signature standard recommandée :

# %%
def my_plotter(ax, data_1, data_2, param_dict):
  """ some stuff"""
  out = ax.plot(data_1, data_2, **param_dict)
  return out

d1, d2, d3, d4 = np.random.randn(4, 100)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 9))
my_plotter(ax1, d1, d2, {'marker': 'x'})
my_plotter(ax2, d3, d4, {'marker': 'o'})

# %% [markdown]
# ## Artistes de styling

# %%
fig, ax = plt.subplots(figsize=(16, 9))
x = np.arange(len(d1))
ax.plot(x, np.cumsum(d1), color='blue', linewidth=3, linestyle='--')
l, = ax.plot(x, np.cumsum(d2), color='orange', linewidth=2)
l.set_linestyle(':')

# %% [markdown]
# #### Couleurs

# %%
fig, ax = plt.subplots(figsize=(16, 9))
ax.scatter(d1, d2, s=500, facecolor='C1', edgecolor='k')

# %% [markdown]
# ### Largeur et styles des lignes, taille des marqueurs

# %%
fig, ax = plt.subplots(figsize=(16, 9))
ax.plot(d1, 'o', label='data 1')
ax.plot(d2, 'd', label='data 2')
ax.plot(d3, 'v', label='data 3')
ax.plot(d4, 's', label='data 4')
ax.legend();

# %% [markdown]
# ## Annoter les tracés

# %% [markdown]
# ### Annotations d'axes et texte
#
# 1. $\mu, \sigma \leftarrow 115, 15$
# 2. $x \leftarrow \mu + \sigma \times r_{n, 10000}$
#
# [Wikipédia : Loi normale](https://fr.wikipedia.org/wiki/Loi_normale)
#
# Loi de probabilité aboslument continue qui dépend de deux paramètres : son espérance $\mu$, réelle, et son écart-type $\sigma$.
#
# Définition : $f(x)=\frac{1}{\sigma\sqrt{2\pi}}e^{\frac{1}{2}\left(\frac{x-\mu}{\sigma}\right)^2}$

# %%
mu, sigma = 115, 15
x = mu + sigma * np.random.randn(10000)
display(x)
fig, ax = plt.subplots(figsize=fig_shape)#, layout='constrained')
# the histogram of the data
n, bins, patches = ax.hist(x, 50, density=1, facecolor='C0', alpha=0.75)

ax.set_xlabel('Length [cm]', fontsize=13)
ax.set_ylabel('Probability', fontsize=13)
ax.set_title('Aardvark lengths\n (not really)', fontsize=18)
ax.text(75, .025, r'$\mu=115,\ \sigma=15$', fontsize=15)
ax.axis([55, 175, 0, 0.03])
ax.grid(True)
# Out:
# array([128.5064198 , 133.18309143,  96.86271817, ..., 115.2478428 ,
#        136.85779108, 149.84015441])

# %% [markdown]
# #### Ma fonction de tracé de plusieurs variations de la loi normale
#
# Reproduction du 1er schéma de la page wikipedia sur l'esp

# %%
from scipy.stats import norm
import statistics

# def norm_plot(mu, sigma, x):
# proto
  
a, b, n = -50, 50, 10000
x = np.linspace(a, b, n)
# display(x)

m1, s1 = statistics.mean(x), statistics.stdev(x)
m2, s2 = m1 + 20, s1 / 2
m3, s3 = m1 + 10, s1 * 2
m4, s4 = m1 - 10, s1 / 3

y1 = norm.pdf(x, m1, s1)
# display(y1)
y2 = norm.pdf(x, m2, s2)
# display(y2)
y3 = norm.pdf(x, m3, s3)
# display(y2)
y4 = norm.pdf(x, m4, s4)
# display(y2)

plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.plot(x, y4)

# %% [markdown]
# #### Généralisation en fonction

# %%
from scipy.stats import norm
import statistics

# def norm_plot(mu, sigma, x):
# proto
  
a1, b1, n1 = -50, 50, 10000
x1 = np.linspace(a1, b1, n1)
x = [x1, x1 / 2, x1 * 2, x1 + 25]
# display(x)

m1, s1 = np.mean(x), np.std(x)
p = [
    (m1, s1),
     (m1 + 20, s1 / 2),
     (m1 + 10, s1 * 2),
     (m1 - 10, s1 / 3)
]


# display(p)
def norm_plots(p, x):
  y = [norm.pdf(x, *p[i]) for i in range(len(p))]
  for i in range(len(p)):
    plt.plot(x[i], *y[i])
  plt.show()

# on fait une simple association entre les n x_i et les n p_i
# d'autres associations, notamment matricielles peuvent être envisagées (ex. produit cartésien)
def norm_plots_p_x(p_, x_):
  fig, ax = plt.subplots(figsize=(16, 9))
  ax.set_title('coucou')
  ax.set_ylim(0.002, 0.05)
  ax.grid(True)
  [ax.plot(x, norm.pdf(x, *p)) for x, p in zip(x_, p_)]
  plt.show()

norm_plots_p_x(p, x)

# %% [markdown]
# ### Annotations

# %%
fig, ax = plt.subplots(figsize=(16, 9))

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2 * np.pi * t)
line, = ax.plot(t, s, lw=2)

ax.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05))

ax.set_ylim(-2, 2);

# %% [markdown]
# ### Légendes

# %%
fig, ax = plt.subplots(figsize=(16, 9))
ax.plot(np.arange(len(d1)), d1, label='data1')
ax.plot(np.arange(len(d2)), d2, label='data2')
ax.plot(np.arange(len(d3)), d3, 'd', label='data3')
ax.legend();

# %% [markdown]
# ## Echelle et graduation des axes

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 9)) #, layout='constrained')
xdata = np.arange(len(d1))  # make an ordinal for this
data = 10**d1
axs[0].plot(xdata, data)

axs[1].set_yscale('log')
axs[1].plot(xdata, data);

# %% [markdown]
# ## Combinaison avec le logarithme

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter, FixedLocator

# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the interval ]0, 1[
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
fig, axs = plt.subplots(3, 2, figsize=(6, 8),
                        constrained_layout=True)

# linear
ax = axs[0, 0]
ax.plot(x, y)
ax.set_yscale('linear')
ax.set_title('linear')
ax.grid(True)


# log
ax = axs[0, 1]
ax.plot(x, y)
ax.set_yscale('log')
ax.set_title('log')
ax.grid(True)


# symmetric log
ax = axs[1, 1]
ax.plot(x, y - y.mean())
ax.set_yscale('symlog', linthresh=0.02)
ax.set_title('symlog')
ax.grid(True)

# logit
ax = axs[1, 0]
ax.plot(x, y)
ax.set_yscale('logit')
ax.set_title('logit')
ax.grid(True)


# Function x**(1/2)
def forward(x):
    return x**(1/2)


def inverse(x):
    return x**2


ax = axs[2, 0]
ax.plot(x, y)
ax.set_yscale('function', functions=(forward, inverse))
ax.set_title('function: $x^{1/2}$')
ax.grid(True)
ax.yaxis.set_major_locator(FixedLocator(np.arange(0, 1, 0.2)**2))
ax.yaxis.set_major_locator(FixedLocator(np.arange(0, 1, 0.2)))


# Function Mercator transform
def forward(a):
    a = np.deg2rad(a)
    return np.rad2deg(np.log(np.abs(np.tan(a) + 1.0 / np.cos(a))))


def inverse(a):
    a = np.deg2rad(a)
    return np.rad2deg(np.arctan(np.sinh(a)))

ax = axs[2, 1]

t = np.arange(0, 170.0, 0.1)
s = t / 2.

ax.plot(t, s, '-', lw=2)

ax.set_yscale('function', functions=(forward, inverse))
ax.set_title('function: Mercator')
ax.grid(True)
ax.set_xlim([0, 180])
ax.yaxis.set_minor_formatter(NullFormatter())
ax.yaxis.set_major_locator(FixedLocator(np.arange(0, 90, 10)))

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:37: MatplotlibDeprecationWarning: SymmetricalLogScale got an unexpected keyword argument 'linthresh'. In the future this will raise TypeError

# %% [markdown]
# ### Position et format des graduations

# %%
fig, axs = plt.subplots(2, 1) #, layout='constrained')
axs[0].plot(xdata, d1)
axs[0].set_title('Automatic ticks')

axs[1].plot(xdata, d1)
axs[1].set_xticks(np.arange(0, 100, 30), ['zero', '30', 'sixty', '90'])
axs[1].set_yticks([-1.5, 0, 1.5])  # note that we don't need to specify labels
axs[1].set_title('Manual ticks')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
# Text(0.5, 1.0, 'Manual ticks')

# %% [markdown]
# ## Personnaliser Matplotlib avec des feuille de style et rcParams
#
# https://matplotlib.org/stable/tutorials/introductory/customizing.html?highlight=style

# %% [markdown]
# There are three ways to customize Matplotlib:
# 1. Setting rcParams at runtime.
# 2. Using style sheets.
# 3. Changing your matplotlibrc file.

# %% [markdown]
# ### Runtime rc settings

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from cycler import cycler
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['lines.linestyle'] = '--'
data = np.random.randn(50)
plt.plot(data)

# %%
print('type(mpl.rcParams) :', type(mpl.rcParams))
# print('mpl.rcParams (' + str(len(mpl.rcParams)) + ') :', mpl.rcParams)
print()

axes_params = {k:p for k, p in mpl.rcParams.items() if k.startswith('axes.')}
print('type(axes_params) :', type(axes_params))
# print('mpl.rcParams<axes> (' + str(len(axes_params)) + ') :', mpl.RcParams(axes_params))
print()

import re
t = 'animation.avconv_args.truc.machin'
s = r'[^.]+'
_t = re.findall(s, t)
print(_t)

def get_subparams(rcp, pfx):
  return mpl.RcParams({k:p for k, p in rcp.items() if k.startswith(pfx)})

def get_prefixes(rcp):
  l = list(set([re.search(r'^([^.]+)', p).group(1) for p in rcp]))
  l.sort()
  return l

print('main groups :', get_prefixes(mpl.rcParams))

# La suite est dans pr_utils et pr_plt
# Out:
# type(mpl.rcParams) : <class 'matplotlib.RcParams'>
#
# type(axes_params) : <class 'dict'>
#
# ['animation', 'avconv_args', 'truc', 'machin']
# main groups : ['_internal', 'agg', 'animation', 'axes', 'axes3d', 'backend', 'backend_fallback', 'boxplot', 'contour', 'datapath', 'date', 'docstring', 'errorbar', 'figure', 'font', 'grid', 'hatch', 'hist', 'image', 'interactive', 'keymap', 'legend', 'lines', 'markers', 'mathtext', 'mpl_toolkits', 'patch', 'path', 'pdf', 'pgf', 'polaraxes', 'ps', 'savefig', 'scatter', 'svg', 'text', 'timezone', 'tk', 'toolbar', 'verbose', 'webagg', 'xtick', 'ytick']

# %%
mpl.rcParams['axes.prop_cycle'] = cycler(color=['r', 'g', 'b', 'y'])
plt.plot(data)  # first color is red
mpl.rc('lines', linewidth=4, linestyle='-.')
plt.plot(data)
plt.show()

# %%
mpl.rc('lines', linewidth=4, linestyle='-.')
plt.plot(data)
plt.show()

# %% [markdown]
# ### Teporary rc settings (with rc_context)

# %%
with mpl.rc_context({'lines.linewidth': 2, 'lines.linestyle': ':'}):
    plt.plot(data)

# %%
""" les décorateurs ne fonctionnent-ils pas en notebook ?
@mpl.rc_context({'lines.linewidth': 3, 'lines.linestyle': '-'})
def plotting_function():
    plt.plot(data)

plotting_function()"""
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-834255946d47> in <module>()
# ----> 1 @mpl.rc_context({'lines.linewidth': 3, 'lines.linestyle': '-'})
#       2 def plotting_function():
#       3     plt.plot(data)
#       4
#       5 plotting_function()
#
# TypeError: 'rc_context' object is not callable

# %%
mpl.rcdefaults() # retour aux paramètres par défaut

# %% [markdown]
# ### Utilisation de feuilles de style

# %%
print(plt.style.available)
# 'Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot',
# 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette',
# 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel',
# 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10'
for style in plt.style.available:
  plt.style.use(style)
  fig, ax = plt.subplots()
  ax.set_title(style)
  ax.plot(data)
  plt.show()
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# ...

# %%
mpl_cfg_dir = mpl.get_configdir() # mettre mon style dans ce dossier pour pouvoir ensuite faire plt.style.use(my_style)
# %ls -la {mpl_cfg_dir}
# Out:
# total 8
# drwxr-xr-x 2 root root 4096 Aug  4 13:41 ./
# drwx------ 4 root root 4096 Aug  4 13:41 ../

# %%
  plt.style.use(['dark_background', 'seaborn-colorblind']) # combinaison, le plus à droite écrase les précédents
  fig, ax = plt.subplots()
  ax.set_title(style)
  ax.plot(data)
  plt.show()

# %%
with plt.style.context('dark_background'):
    plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')
plt.show()

# %%
mpl.matplotlib_fname()
# Out:
# '/usr/local/lib/python3.7/dist-packages/matplotlib/mpl-data/matplotlibrc'

# %% [markdown]
# # Mes défis

# %% [markdown]
# ## Vue de la palette suivant un gradient (coloré) continu

# %%
# code from : https://stackoverflow.com/questions/43000500/change-pyplot-axes-text-color-to-white
import matplotlib.pyplot as plt
import numpy as np
params = {"ytick.color" : 'k',
          "xtick.color" : 'k',
          "axes.labelcolor" : 'k',
          "axes.edgecolor" : 'k'}
plt.rcParams.update(params)

a = np.array([[319.785, 198.988]])
fig = plt.figure(figsize=(10, 1))
# set facecolor black for testing:
# fig.set_facecolor('w')

# doc : https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html
img = plt.imshow(a)                     # visu dégradée d'une palette : params cmap='veridis', vmin=0, vmax=255

# doc : https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.gca.html?highlight=gca#matplotlib.pyplot.gca
# GCA (Get Current Axes) -> test len(fig.axes)
plt.gca().set_visible(False)
# doc : https://matplotlib.org/stable/api/_as_gen/matplotlib.artist.Artist.set_visible.html?highlight=set_visible
# set_visible est une méthode héritée par Axes de Artist -> c'est la classe Artist et le modèle de classes qu'il faut comprendre
# ici, on masque l'Axes par défaut
# nb > j'aurais plutôt écrit : fig.axes[0].set_visible(False)

#
cax = plt.axes([0, .3, 1, 0.5])
# doc : https://matplotlib.org/stable/api/colorbar_api.html?highlight=colorbar#module-matplotlib.colorbar
cb = plt.colorbar(orientation='horizontal', cax=cax)


plt.show()

# %%
# code from : https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_adjust.html#sphx-glr-gallery-subplots-axes-and-figures-subplots-adjust-py
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)

plt.subplot(211)
plt.imshow(np.random.random((100, 100)))
plt.subplot(212)
plt.imshow(np.random.random((100, 100)))

plt.subplots_adjust(bottom=0.1, right=0.8, top=0.9)
cax = plt.axes([0.85, 0.1, 0.075, 0.8])
plt.colorbar(cax=cax)

plt.show()

# %% [markdown]
# # Old, recycler

# %% [markdown]
# ## Un exemple

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.path import Path
from matplotlib.patches import PathPatch

xx = np.arange(0, 10, 0.01)
yy = xx * np.exp(-xx)

path = Path(np.array([xx,yy]).transpose())
patch = PathPatch(path, facecolor='none')
plt.gca().add_patch(patch)

im = plt.imshow(xx.reshape(yy.size, 1), cmap=plt.cm.Reds,interpolation="bicubic",
                origin='lower', extent=[0,10,-0.0,0.40], aspect="auto", clip_path=patch, clip_on=True)
#im.set_clip_path(patch)
plt.savefig('img/x_exp_minus_x.png', transparent=True)

# %% [markdown]
# ## Colormaps
#
# https://matplotlib.org/stable/tutorials/colors/colormaps.html
#
# Documentation on the colormaps : https://gist.github.com/endolith/2719900#id7

# %% [markdown]
# ### Plot color grandients

# %%
cmaps = {}

gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))


def plot_color_gradients(category, cmap_list):
    # Create figure and adjust figure height to number of colormaps
    nrows = len(cmap_list)
    figh = 0.35 + 0.15 + (nrows + (nrows - 1) * 0.1) * 0.22
    fig, axs = plt.subplots(nrows=nrows + 1, figsize=(6.4, figh))
    fig.subplots_adjust(top=1 - 0.35 / figh, bottom=0.15 / figh,
                        left=0.2, right=0.99)
    axs[0].set_title(f'{category} colormaps', fontsize=14)

    for ax, name in zip(axs, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=plt.get_cmap(name))
        ax.text(-0.01, 0.5, name, va='center', ha='right', fontsize=10,
                transform=ax.transAxes)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axs:
        ax.set_axis_off()

    # Save colormap list for later.
    cmaps[category] = cmap_list

# %%
plot_color_gradients('Perceptually Uniform Sequential',
                     ['viridis', 'plasma', 'inferno', 'magma', 'cividis'])
plt.savefig('img/perceptually_uniform_sequential_colormaps.png', transparent=True)

# %%
plot_color_gradients('Sequential',
                     ['Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
                      'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
                      'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn'])
plt.savefig('img/sequential_colormaps.png', transparent=True)

# %%
plot_color_gradients('Sequential (2)',
                     ['binary', 'gist_yarg', 'gist_gray', 'gray', 'bone',
                      'pink', 'spring', 'summer', 'autumn', 'winter', 'cool',
                      'Wistia', 'hot', 'afmhot', 'gist_heat', 'copper'])
plt.savefig('img/sequential_2_colormaps.png', transparent=True)

# %%
plot_color_gradients('Diverging',
                     ['PiYG', 'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu', 'RdYlBu',
                      'RdYlGn', 'Spectral', 'coolwarm', 'bwr', 'seismic'])
plt.savefig('img/diverging_colormaps.png', transparent=True)

# %%
plot_color_gradients('Cyclic', ['twilight', 'twilight_shifted', 'hsv'])
plt.savefig('img/cyclic_colormaps.png', transparent=True)

# %%
plot_color_gradients('Qualitative',
                     ['Pastel1', 'Pastel2', 'Paired', 'Accent', 'Dark2',
                      'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b',
                      'tab20c'])
plt.savefig('img/qualitative_colormaps.png', transparent=True)

# %%
plot_color_gradients('Miscellaneous',
                     ['flag', 'prism', 'ocean', 'gist_earth', 'terrain',
                      'gist_stern', 'gnuplot', 'gnuplot2', 'CMRmap',
                      'cubehelix', 'brg', 'gist_rainbow', 'rainbow', 'jet',
                      'nipy_spectral', 'gist_ncar']) # 'turbo', not a valid name
plt.savefig('img/miscellaneous_colormaps.png', transparent=True)

# %% [markdown]
# ## Getting started
#
# [plt.subplots](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html?highlight=subplots#matplotlib.pyplot.subplots)
#
# [mpl.Axes.plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.plot.html?highlight=plot#matplotlib.axes.Axes.plot)
#
# [plt.show](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.show.html?highlight=show#matplotlib.pyplot.show)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 200)    # create 200 evenly spaced samples, calculated over the interval [0, 2π].
y = np.sin(x)                         # create (sin(0), .., sin(2π))

fig, ax = plt.subplots()              # create a figure and a set of subplots
ax.plot(x, y)                         # plot x and y using default line style and color
plt.show()                            # display all open figures

# %% [markdown]
# ### Plot types

# %% [markdown]
# #### Basics

# %%
import matplotlib.pyplot as plt
display(plt.style.available)     # because the mpl-gallery is not available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# ##### plot(x, y)
#
# [mpl.style.use](https://matplotlib.org/stable/api/style_api.html?highlight=style%20use#matplotlib.style.use)
#
# [Customizing Matplotlib with style sheets and rcParams](https://matplotlib.org/stable/tutorials/introductory/customizing.html)
#
# [mpl.Axes.set](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set.html)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn-pastel')               # Use Matplotlib style settings from a style specification.

# make data
x = np.linspace(0, 10, 100)                   # (0, 0.1, .., 99.9, 100)
y = 4 + 2 * np.sin(2 * x)                     # 4 + 2.sin(0, 0.1, .., 99.9, 100)

# plot
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)                  # plot x, y with defaults but set the line width to 2 points

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),   # set the axis interval and ticks
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# ##### scatter(x, y)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_classic_test_patch')

# make the data
np.random.seed(3)
x = 4 + np.random.normal(0, 2, 24)
y = 4 + np.random.normal(0, 2, len(x))
# size and color:
sizes = np.random.uniform(15, 80, len(x))
colors = np.random.uniform(15, 80, len(x))

# plot
fig, ax = plt.subplots()

ax.scatter(x, y, s=sizes, c=colors, vmin=0, vmax=100)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# # Seaborn

# %% [markdown]
# ### Thèmes

# %%
#There are five preset seaborn themes: darkgrid, whitegrid, dark, white, and ticks.
sns_themes = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']
for theme in sns_themes:
  sns.set_style(theme)
  plt.figure(figsize=(16, 9))
  data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
  #display(data)
  print(bold(theme.upper()))
  sns.boxplot(data=data)
  plt.show()

# %% [markdown]
# ### Palettes
#
# http://seaborn.pydata.org/tutorial/color_palettes.html https://chrisalbon.com/code/python/data_visualization/seaborn_color_palettes/

# %%
sns.palplot(sns.color_palette()) # default palette : quali(10 colors)

sns.palplot(sns.color_palette('deep', 10))

# qualitative color palettes
sns.palplot(sns.color_palette('tab10'))

## quali - circular color system
sns.palplot(sns.color_palette('hls', 16))
sns.palplot(sns.color_palette('husl', 8))

## quali color brwer palettes
sns.palplot(sns.color_palette('Set2'))
sns.palplot(sns.color_palette('Paired'))


# sequential color palettes
sns.palplot(sns.color_palette('rocket', 15)) #, as_cmap=True)) : retourne une plt.colors.Colormap
plt.savefig('img/rocket_palette_15.png', transparent=True)

# %%
"""
gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))
ax.imshow(gradient, aspect='auto', cmap=plt.get_cmap(name))
"""

# %% [markdown]
# # Examples

# %% [markdown]
# ## Boxplot and themes

# %%
#There are five preset seaborn themes: darkgrid, whitegrid, dark, white, and ticks.
sns_themes = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']
for theme in sns_themes:
  sns.set_style(theme)
  plt.figure(figsize=(16, 9))
  data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
  #display(data)
  print(bold(theme.upper()))
  sns.boxplot(data=data)
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c825884a03be> in <module>()
#       6   data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
#       7   #display(data)
# ----> 8   print(bold(theme.upper()))
#       9   sns.boxplot(data=data)
#      10   plt.show()
#
# NameError: name 'bold' is not defined

# %% [markdown]
# ## Exemple StackOverFlow
#
# https://stackoverflow.com/questions/68895009/have-gradient-colours-in-sns-pairplot-for-one-column-of-dataframe-so-that-i-can

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import seaborn as sns
import pandas as pd
import numpy as np

def myFunc(x):
    myReturn = x + 1 * np.random.random(x.shape[0])
    return myReturn

np.random.seed(1)
a = np.arange(0, 10, 0.1)
np.random.rand()

b = myFunc(a)
c = a * np.sin(a)
df = pd.DataFrame({'a': a, 'b': b, 'c': c})

cmap = LinearSegmentedColormap.from_list('blue-yellow', ['gold', 'lightblue', 'darkblue'])  # plt.get_cmap('viridis_r')
g = sns.pairplot(df, corner=True)
for ax in g.axes.flat:
    if ax is not None and not ax in g.diag_axes:
        for collection in ax.collections:
            collection.set_cmap(cmap)
            collection.set_array(df['a'])
plt.show()

# %% [markdown]
# ## Un autre exemple
#
# https://pradhanphy.blogspot.com/2014/06/filling-between-curves-with-color.html

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.path import Path
from matplotlib.patches import PathPatch

xx = np.arange(0, 10, 0.01)
yy = xx * np.exp(-xx)

path = Path(np.array([xx,yy]).transpose())
patch = PathPatch(path, facecolor='none')
plt.gca().add_patch(patch)

im = plt.imshow(xx.reshape(yy.size, 1), cmap=plt.cm.Reds,interpolation="bicubic",
                origin='lower', extent=[0, 10, -0.0, 0.40], aspect="auto", clip_path=patch, clip_on=True)
#im.set_clip_path(patch)
plt.savefig('img/x_exp_minus_x.png', transparent=True)

# %% [markdown]
# # Local lib

# %% [markdown]
# ## Utils

# %% [markdown]
# ### Connection to GDrive

# %%
from google.colab import drive

def gdrive_connect():
  drive.mount('/content/drive')

gdrive_connect()

# %%
# DBG : check
! ls -la "/content/drive/My Drive/Colab Notebooks/Franck | OS DS P2 | Academy WBE Dataset"
