# %% [markdown]
# <mark>Faire mieux qu'un dictionnaire de traductions, faire un index et glossaire !</mark>
#
# Récupérer tout ce que j'ai déjà enregistré dans :
# * mon journal
# * le journal de formation
# * les doc de projet

# %% [markdown]
# # Nouvelles entrées à intégrer
#
# * *dépendance partielle*
# * **classifier** : *classifieur* (et non *classificateur*)
# * **feature** : *caractéristique* (et non *fonctionnalité*, ni *entité*)
#
# Toutes les références enregistrées dans les journaux et non encore classées
#
# Lien vers les fiches traduites quand elles l'ont été + les priorités de traduction.
#
# Sortir les inserts dans les cours.

# %% [markdown]
# #### [**Kaniadakis statistics**](https://en.wikipedia.org/wiki/Kaniadakis_statistics) (*Statistique de Kaniadakis*)

# %% [markdown]
# #### ⦿ [**Goodness of fit**](https://en.wikipedia.org/wiki/Goodness_of_fit) ([*Qualité de l'ajustement*](https://fr.wikipedia.org/wiki/Qualité_de_l'ajustement))
#
# The **goodness of fit** of a **statistical model** describes how well it fits a set of observations. Measures of goodness of fit typically summarize the discrepancy between observed values and the values expected under the model in question. Such measures can be used in **statistical hypothesis testing**, e.g. to **test for normality** of **residuals**, to test whether two samples are drawn from identical distributions (see **Kolmogorov–Smirnov** test), or whether outcome frequencies follow a specified distribution (see **Pearson's chi-square test**). In the **analysis of variance**, one of the components into which the variance is partitioned may be a **lack-of-fit sum of squares**.
#
# ---
#
# La **qualité d'ajustement** d'un **modèle statistique** décrit dans quelle mesure il s'ajuste à un ensemble d'observations. Les mesures de la qualité de l'ajustement résument généralement l'écart entre les valeurs observées et les valeurs attendues dans le cadre du modèle en question. Ces mesures peuvent être utilisées dans les **tests d'hypothèses statistiques**, par ex. pour **tester la normalité** des **résidus**, pour tester si deux échantillons sont tirés de distributions identiques (voir **test de Kolmogorov-Smirnov**), ou si les fréquences des résultats suivent une distribution spécifiée (voir **Pearson's test du chi carré**). Dans l'**analyse de la variance**, l'une des composantes dans lesquelles la variance est répartie peut être une **somme des carrés sans ajustement**.

# %% [markdown]
# #### ⦿ [**Studentized residual**](https://en.wikipedia.org/wiki/Studentized_residual) (*Résidu studentisé*)
#
# In statistics, a **studentized residual** is the quotient resulting from the division of a **residual** by an **estimate** of its **standard deviation**. It is a form of a **Student's t-statistic**, with the estimate of error varying between points.
#
# This is an important technique in the detection of **outliers**. It is among several named in honor of **William Sealey Gosset**, who wrote under the pseudonym *Student*. Dividing a statistic by a **sample standard deviation** is called *studentizing*, in analogy with **standardizing** and **normalizing**.
#
# ---
#
# En statistique, un **résidu studentisé** est le quotient résultant de la division d'un **résidu** par une **estimation** de son **écart type**. Il s'agit d'une forme de **statistique t de Student**, l'estimation de l'erreur variant d'un point à l'autre.
#
# Il s'agit d'une technique importante dans la détection des **valeurs aberrantes**. Il fait partie de plusieurs nommés en l'honneur de **William Sealey Gosset**, qui a écrit sous le pseudonyme *Student*. La division d'une statistique par un **écart-type d'échantillon** s'appelle *studentizing*, par analogie avec **standardizing** et **normalizing**.

# %% [markdown]
# #### ⦿ [**Gauss–Markov theorem**](https://en.wikipedia.org/wiki/Gauss-Markov_theorem) ([*Théorème de Gauss-Markov*](https://fr.wikipedia.org/wiki/Théorème_de_Gauss-Markov))
#
# In **statistics**, the **Gauss–Markov theorem** (or simply **Gauss theorem** for some authors)[1] states that the **ordinary least squares** (OLS) estimator has the lowest **sampling variance** within the **class** of **linear unbiased estimators**, if the **errors** in the **linear regression model** are **uncorrelated**, have **equal variances** and expectation value of zero.[2] The errors do not need to be **normal**, nor do they need to be **independent and identically distributed** (only **uncorrelated** with mean zero and **homoscedastic** with finite variance). The requirement that the estimator be unbiased cannot be dropped, since biased estimators exist with lower variance. See, for example, the **James–Stein estimator** (which also drops linearity), **ridge regression**, or simply any **degenerate** estimator.
#
# ---
#
# En **statistiques**, le **théorème de Gauss–Markov** (ou simplement le **théorème de Gauss** pour certains auteurs)[1] stipule que l'estimateur des **moindres carrés ordinaires** (OLS) a le plus basse **variance d'échantillonnage** dans la **classe** des **estimateurs linéaires sans biais**, si les **erreurs** du **modèle de régression linéaire** sont **non corrélées**, ont des **variances égales** et valeur d'espérance de zéro.[2] Les erreurs n'ont pas besoin d'être **normales**, ni d'être **indépendantes et distribuées de manière identique** (seulement **non corrélées** avec une moyenne nulle et **homoscédastiques** avec une variance finie). L'exigence que l'estimateur soit sans biais ne peut pas être abandonnée, car il existe des estimateurs biaisés avec une variance plus faible. Voir, par exemple, l'**estimateur James-Stein** (qui supprime également la linéarité), la **régression ridge** ou simplement tout estimateur **dégénéré**.

# %% [markdown]
# #### ⦿ [**Homoscedasticity and heteroscedasticity**](https://en.wikipedia.org/wiki/Homoscedasticity_and_heteroscedasticity)
#
# In **statistics**, a **sequence** (or a vector) of **random variables** is **homoscedastic** if all its random variables have the same finite **variance**. This is also known as **homogeneity of variance**. The complementary notion is called **heteroscedasticity**. The spellings *homoskedasticity* and *heteroskedasticity* are also frequently used.[1][2][3]
#
# Assuming a variable is homoscedastic when in reality it is heteroscedastic results in unbiased but inefficient point estimates and in biased estimates of standard errors, and may result in overestimating the **goodness of fit** as measured by the **Pearson coefficient**.
#
# The existence of heteroscedasticity is a major concern in **regression analysis** and the **analysis of variance**, as it invalidates **statistical tests of significance** that assume that the **modelling errors** all have the same variance. While the **ordinary least squares** estimator is still unbiased in the presence of heteroscedasticity, it is inefficient and **generalized least squares** should be used instead.[4][5]
#
# Because heteroscedasticity concerns **expectations** of the second **moment** of the errors, its presence is referred to as **misspecification** of the second order.[6]
#
# The **econometrician** **Robert Engle** was awarded the 2003 **Nobel Memorial Prize for Economics** for his studies on **regression analysis** in the presence of heteroscedasticity, which led to his formulation of the **autoregressive conditional heteroscedasticity** (ARCH) modeling technique.[7]
#
# ---
#
# En **statistiques**, une **séquence** (ou un vecteur) de **variables aléatoires** est **homoscédastique** si toutes ses variables aléatoires ont la même **variance** finie. Ceci est également connu sous le nom d'**homogénéité de la variance**. La notion complémentaire est appelée **hétéroscédasticité**. Les orthographes *homoskedasticity* et *heteroskedasticity* sont également fréquemment utilisées.[1][2][3]
#
# Supposer qu'une variable est homoscédastique alors qu'en réalité elle est hétéroscédastique donne des estimations ponctuelles non biaisées mais inefficaces et des estimations biaisées des erreurs types, et peut entraîner une surestimation de la **qualité de l'ajustement** telle que mesurée par le **coefficient de Pearson**.
#
# L'existence d'hétéroscédasticité est une préoccupation majeure dans l'**analyse de régression** et l'**analyse de variance**, car elle invalide les **tests statistiques de signification** qui supposent que les **erreurs de modélisation** ont toutes la même variance. Bien que l'estimateur des **moindres carrés ordinaires** soit toujours sans biais en présence d'hétéroscédasticité, il est inefficace et les **moindres carrés généralisés** doivent être utilisés à la place.
#
# Comme l'hétéroscédasticité concerne les **attentes** du deuxième **moment** des erreurs, sa présence est appelée **spécification erronée** du second ordre.[6]
#
# L'**économètre** **Robert Engle** a reçu le **prix Nobel d'économie** en 2003 pour ses études sur l'**analyse de régression** en présence d'hétéroscédasticité, ce qui l'a conduit à la formulation de la technique de modélisation **hétéroscédasticité conditionnelle autorégressive** (ARCH).[7]

# %% [markdown]
# ## [⚓](https://en.wikipedia.org/wiki/Category:Probability_theory) [**Probability theory**](https://en.wikipedia.org/wiki/Probability_theory) ([*Théorie des probabilités*](https://fr.wikipedia.org/wiki/Théorie_des_probabilités))
#
# * ⚓ Probability theorists (1 C, 335 P)
# * ⚓ Conditional probability (2 C, 14 P)
# * ⚓ Decision theory (4 C, 72 P)
# * ⚓ Dempster–Shafer theory (4 P)
# * ⚓ Exotic probabilities (1 C, 9 P)
# * ⚓ Free probability theory (3 P)
# * ⚓ Experiment (probability theory) (14 P)
# * ⚓ Independence (probability theory) (3 C, 28 P)
# * ⚓ Large deviations theory (11 P)
# * ⚓ Probabilistic arguments (13 P)
# * ⚓ [**Probabilistic models**](https://en.wikipedia.org/wiki/Category:Probabilistic_models) (2 C, 32 P)
# * ⚓ Probability bounds analysis (6 P)
# * ⚓ Probability distributions (12 C, 23 P)
# * ⚓ Probability interpretations (1 C, 20 P)
# * ⚓ Probability problems (29 P)
# * ⚓ Probability theorems (3 C, 101 P)
# * ⚓ Probability theory paradoxes (20 P)
# * ⚓ Random variable ordering (4 P)
# * ⚓ Stability (probability) (1 C, 5 P)
# * ⚓ Statistical randomness (11 C, 27 P)
# * Probability theory
# * Catalog of articles in probability theory
# * Additive process
# * Additive smoothing
# * Almost surely
# * Augmented filtration
# * Big O in probability notation
# * Blumenthal's zero–one law
# * Carleman's condition
# * Central tendency
# * Chain rule (probability)
# * Chvátal–Sankoff constants
# * Collectively exhaustive events
# * Complete filtration
# * Complex random variable
# * Complex random vector
# * Contiguity (probability theory)
# * Continuum percolation theory
# * Convergence of Probability Measures
# * Coupling (probability)
# * Covariance operator
# * Decoupling (probability)
# * Dual total correlation
# * Dynkin system
# * Ε-net (computational geometry)
# * Empirical characteristic function
# * Exotic probability
# * Exponentially equivalent measures
# * Fat Chance: Probability from 0 to 1
# * Filtered probability space
# * Filtration (probability theory)
# * Geometric probability
# * Graphoid
# * Graphon
# * Hajek projection
# * High-dimensional statistics
# * Ibragimov–Iosifescu conjecture for φ-mixing sequences
# * Impossibility of a gambling system
# * Imprecise probability
# * Inclusion–exclusion principle
# * Independent increments
# * Independent S-increments
# * Indicator function
# * Inductive probability
# * Intensity measure
# * Isotropic measure
# * Law of truly large numbers
# * Lévy–Prokhorov metric
# * The Mathematics of Games and Gambling
# * Mixture (probability)
# * Pairwise error probability
# * Pascal's wager
# * Possibility theory
# * Principle of indifference
# * Probabilistic argumentation
# * Probability axioms
# * Probability interpretations
# * Probability vector
# * Radical probabilism
# * Right-continuous filtration
# * Set-theoretic limit
# * Statistical interference
# * Sub-probability measure
# * Total correlation
# * Total variation distance of probability measures
# * Transition kernel
# * Typical set
# * Uncertainty theory
# * Unit measure
# * Usual hypotheses
# * Wald's equation
# * With high probability
# * Zero–one law

# %% [markdown]
# ### [⚓](https://en.wikipedia.org/wiki/Category:Probability_distributions) [**Probability distribution**](https://en.wikipedia.org/wiki/Probability_distribution) (12 C (?? P), 22 P)
#
# * ⚓ Theory of probability distributions (12 C, 72 P)
# * * ⚓ Characterization of probability distributions (6 P)
# * * ⚓ Estimation of densities (9 P)
# * * ⚓ Functions related to probability distributions (15 P)
# * * ⚓ Information geometry (1 C, 5 P)
# * *  * ⇒⚓ Statistical distance (2 C, 37 P)
# * * ⚓ Martingale theory (25 P)
# * * ⚓ Moment (mathematics) (25 P)
# * * ⚓ Non-uniform random numbers (11 P)
# * * ⚓ Probabilistic inequalities (52 P)
# * * ⚓ Probability distribution fitting (8 P)
# * * ⚓ Statistical parameters (6 P)
# * * ⚓ Tails of probability distributions (10 P)
# * * ⚓ Types of probability distributions (38 P)
# * ⚓ Complex distributions (3 P)
# * ⚓ Compound probability distributions (22 P)
# * ⚓ Conjugate prior distributions (21 P)
# * ⚓ Continuous distributions (3 C, 177 P)
# * * ⚓ Exponential family distributions (2 C, 37 P)
# * * * ⚓ Normal distribution (2 C, 53 P)
# * * * * ⚓ Central limit theorem (10 P)
# * * * * ⚓ Normality tests (11 P)
# * * * ⚓ Poisson distribution (1 C, 13 P)
# * * * * ⚓ Poisson point processes (17 P)
# * * ⚓ Geometric stable distributions (6 P)
# * * ⚓ Multivariate continuous distributions (30 P)
# * ⚓ Discrete distributions (2 C, 50 P)
# * * ⚓ Multivariate discrete distributions (5 P)
# * * ⚓ Poisson distribution (1 C, 13 P)
# * * * * ⚓ Poisson point processes (17 P)
# * ⚓ Infinitely divisible probability distributions (1 C, 15 P)
# * * ⚓ Stable distributions (1 C, 8 P)
# * * * ⚓ Geometric stable distributions (6 P)
# * ⚓ Location-scale family probability distributions (15 P)
# * ⚓ Noncentral distributions (5 P)
# * ⚓ Probability distributions with non-finite variance (29 P)
# * ⚓ Stable distributions (1 C, 8 P)
# * * ⚓ Geometric stable distributions (6 P)
# * ⚓ Systems of probability distributions (8 P)

# %% [markdown]
# #### [⚓](https://en.wikipedia.org/wiki/Category:Probability_distributions) [**Probability distribution**](https://en.wikipedia.org/wiki/Probability_distribution) (22 P)

# %% [markdown]
# * [**List of probability distributions**](https://en.wikipedia.org/wiki/List_of_probability_distributions) ([*Liste de lois de probabilité*](https://fr.wikipedia.org/wiki/Liste_de_lois_de_probabilité))
# * [**Probability distribution**](https://en.wikipedia.org/wiki/Probability_distribution) ([Loi de probabilité](https://fr.wikipedia.org/wiki/Loi_de_probabilité))
# * Data generating process
# * Gaussian distribution on a locally compact Abelian group
# * Inverse Dirichlet distribution
# * [**Kaniadakis distribution**](https://en.wikipedia.org/wiki/Kaniadakis_distribution)
# * * Kaniadakis Erlang distribution
# * * Kaniadakis exponential distribution
# * * Kaniadakis Gamma distribution
# * * Kaniadakis Gaussian distribution
# * * Kaniadakis logistic distribution
# * * [**Kaniadakis Weibull distribution**](https://en.wikipedia.org/wiki/Weibull_distribution) ([*Loi de Weibull*](https://fr.wikipedia.org/wiki/Loi_de_Weibull))
# * Marchenko–Pastur distribution
# * Matrix variate Dirichlet distribution
# * [**Laplace distribution**](https://en.wikipedia.org/wiki/Laplace_distribution)
# * * [**Multivariate Laplace distribution**](https://en.wikipedia.org/wiki/Multivariate_Laplace_distribution)
# * * [**Asymmetric Laplace distribution**](https://en.wikipedia.org/wiki/Asymmetric_Laplace_distribution)
# * Multivariate logistic distribution
# * Probabilistic metric space
# * Probability management
# * ProbOnto
# * Q-Gaussian process
# * Rectified Gaussian distribution
# * Regular distribution (economics)
# * Zero degrees of freedom

# %% [markdown]
# #### ⚓ Theory of probability distributions (12 C, 72 P)

# %% [markdown]
# * Group actions in computational anatomy
# * Benford's law
# * Besov measure
# * Bhatia–Davis inequality
# * Cokurtosis
# * Combinant
# * Comonotonicity
# * Concomitant (statistics)
# * Conditional probability distribution
# * Conditional variance
# * Continuity correction
# * Convolution of probability distributions
# * List of convolutions of probability distributions
# * Coskewness
# * Distance correlation
# * Energy distance
# * Evidence lower bound
# * Ewens's sampling formula
# * Expected return
# * Expected value
# * German tank problem
# * Glivenko's theorem (probability theory)
# * Hellinger distance
# * Infinite divisibility (probability)
# * Joint probability distribution
# * Kernel embedding of distributions
# * Khinchin's theorem on the factorization of distributions
# * Khmaladze transformation
# * Law of the unconscious statistician
# * Law of total covariance
# * Law of total cumulance
# * Law of total expectation
# * Law of total variance
# * Lévy metric
# * Limiting density of discrete points
# * Marginal distribution
# * Mean absolute difference
# * Mean-preserving spread
# * Memorylessness
# * Mills ratio
# * Monotone likelihood ratio
# * Nearest neighbour distribution
# * Neutral vector
# * Normalizing constant
# * Normally distributed and uncorrelated does not imply independent
# * Null distribution
# * Pairwise independence
# * Panjer recursion
# * Parametric family
# * Pareto interpolation
# * Popoviciu's inequality on variances
# * Posterior predictive distribution
# * Power law
# * Probability integral transform
# * Probable error
# * Rayleigh test
# * Relationships among probability distributions
# * Rencontres numbers
# * Schrödinger method
# * Shape of a probability distribution
# * Smoothness (probability theory)
# * Stability (probability)
# * Stein discrepancy
# * Stein's method
# * Tail dependence
# * Truncated distribution
# * Truncation (statistics)
# * Unimodality
# * Univariate
# * Ursell function
# * Wasserstein metric
# * Zero bias transform

# %% [markdown]
# ##### ⚓ Characterization of probability distributions (6 P)
#
# * Characterization of probability distributions
# * Cochran's theorem
# * Cramér's decomposition theorem
# * Lukacs's proportion-sum independence theorem
# * Memorylessness
# * Raikov's theorem

# %% [markdown]
# ##### ⚓ Estimation of densities (9 P)
#
# * Density estimation
# * Cluster-weighted modeling
# * Discretization of continuous features
# * Histogram
# * Kernel density estimation
# * Mean integrated squared error
# * Multivariate kernel density estimation
# * Price-Jones curve
# * Variable kernel density estimation

# %% [markdown]
# ##### ⚓ Functions related to probability distributions (15 P)
#
# * Characteristic function (probability theory)
# * Cumulative distribution function
# * Distortion function
# * Empirical characteristic function
# * Error function
# * Fragmentation function
# * Hazard function
# * Marcum Q-function
# * Ogive (statistics)
# * Owen's T function
# * Probability density function
# * Probability-generating function
# * Q-function
# * Quantile function
# * Rank–size distribution

# %% [markdown]
# ##### ⚓ Information geometry (1 C, 5 P)
#
# * Information geometry
# * Chentsov's theorem
# * Dually flat manifold
# * Fisher information metric
# * Kullback–Leibler divergence
# * ⚓ Statistical distance (2 C, 37 P)

# %% [markdown]
# ##### ⚓ Martingale theory (25 P)
#
# * Azuma's inequality
# * Doléans-Dade exponential
# * Doob decomposition theorem
# * Doob martingale
# * Doob–Meyer decomposition theorem
# * Doob's martingale convergence theorems
# * Doob's martingale inequality
# * Fleming–Viot process
# * Forward measure
# * Kazamaki's condition
# * Local martingale
# * Martingale (probability theory)
# * Martingale central limit theorem
# * Martingale difference sequence
# * Martingale representation theorem
# * McDiarmid's inequality
# * Minimal-entropy martingale measure
# * Novikov's condition
# * Optional stopping theorem
# * Semimartingale
# * Sigma-martingale
# * Tanaka's formula
# * Uniform integrability
# * Wald's martingale
# * Wiener process

# %% [markdown]
# ##### ⚓ [**Moment (mathematics)**](https://en.wikipedia.org/wiki/Moment_(mathematics)) (25 P)
#
# * [**Moment (mathematics)**](https://en.wikipedia.org/wiki/Moment_(mathematics))
# * Carleman's condition
# * [**Central moment**](https://en.wikipedia.org/wiki/Central_moment) ([*Moment centré*](https://fr.wikipedia.org/wiki/Moment_(probabilités)#Moment_centré))
# * Cumulant
# * Factorial moment
# * Factorial moment generating function
# * Generalized method of moments
# * Hamburger moment problem
# * Hausdorff moment problem
# * Isserlis' theorem
# * Kurtosis
# * L-moment
# * Mean
# * Method of moments (probability theory)
# * Method of moments (statistics)
# * Moment measure
# * Moment problem
# * Moment-generating function
# * Optimal instruments
# * Second moment method
# * Skewness
# * [**Standardized moment**](https://en.wikipedia.org/wiki/Standardized_moment)
# * Stieltjes moment problem
# * Taylor expansions for the moments of functions of random variables
# * Variance

# %% [markdown]
# ##### ⚓ Non-uniform random numbers (11 P)
#
# * Box–Muller transform
# * Convolution random number generator
# * Indexed search
# * Inverse transform sampling
# * Marsaglia polar method
# * Poisson random numbers
# * Non-uniform random variate generation
# * Ratio of uniforms
# * Rejection sampling
# * Slice sampling
# * Ziggurat algorithm

# %% [markdown]
# ##### ⚓ Probabilistic inequalities (52 P)
#
# * Azuma's inequality
# * Bennett's inequality
# * Bernstein inequalities (probability theory)
# * Berry–Esseen theorem
# * Boole's inequality
# * Borell–TIS inequality
# * Bretagnolle–Huber inequality
# * BRS-inequality
# * Cantelli's inequality
# * Cauchy–Schwarz inequality
# * Chebyshev's inequality
# * Cheeger bound
# * Chernoff bound
# * Chung–Erdős inequality
# * Concentration inequality
# * Correlation inequality
# * Doob martingale
# * Doob's martingale inequality
# * Eaton's inequality
# * Entropy power inequality
# * Etemadi's inequality
# * Fréchet inequalities
# * Gauss's inequality
# * Gaussian correlation inequality
# * Gaussian isoperimetric inequality
# * Grönwall's inequality
# * Hoeffding's inequality
# * Hoeffding's lemma
# * Hölder's inequality
# * Hsu–Robbins–Erdős theorem
# * Janson inequality
# * Jensen's inequality
# * Khintchine inequality
# * Kolmogorov's inequality
# * Kunita–Watanabe inequality
# * Le Cam's theorem
# * Lenglart's inequality
# * Lorden's inequality
# * Marcinkiewicz–Zygmund inequality
# * Markov's inequality
# * McDiarmid's inequality
# * Multidimensional Chebyshev's inequality
# * Paley–Zygmund inequality
# * Pinsker's inequality
# * Ross's conjecture
# * Sanov's theorem
# * Second moment method
# * Sedrakyan's inequality
# * Stochastic Gronwall inequality
# * Talagrand's concentration inequality
# * Vitale's random Brunn–Minkowski inequality
# * Vysochanskij–Petunin inequality

# %% [markdown]
# ##### ⚓ Probability distribution fitting (8 P)
#
# * Probability distribution fitting
# * Empirical likelihood
# * Maximum likelihood estimation
# * Maximum spacing estimation
# * Method of moments (statistics)
# * Overdispersion
# * Partial likelihood methods for panel data
# * Testing in binary response index models

# %% [markdown]
# ##### ⚓ Statistical parameters (6 P)
#
# * Statistical parameter
# * Concentration parameter
# * Location parameter
# * Noncentral parameter
# * Scale parameter
# * Shape parameter

# %% [markdown]
# ##### ⚓ Tails of probability distributions (10 P)
#
# * 1% rule
# * Extreme value theory
# * Fat-tailed distribution
# * Fisher–Tippett–Gnedenko theorem
# * Heavy-tailed distribution
# * Long tail
# * Long-tail traffic
# * Pareto principle
# * Pickands–Balkema–De Haan theorem
# * Zipf's law

# %% [markdown]
# ##### ⚓ Types of probability distributions (38 P)
#
# * List of probability distributions
# * Symmetric probability distribution
# * Asymptotic distribution
# * Circular distribution
# * Compound probability distribution
# * Degenerate distribution
# * Directional statistics
# * Discrete phase-type distribution
# * Discrete-stable distribution
# * Dyadic distribution
# * Elliptical distribution
# * Exchangeable random variables
# * Exponential family
# * Group family
# * Heavy-tailed distribution
# * Indecomposable distribution
# * Infinite divisibility (probability)
# * Inverse distribution
# * Joint probability distribution
# * Location–scale family
# * Maximum entropy probability distribution
# * Mixed Poisson distribution
# * Natural exponential family
# * NEF-QVF
# * Occupancy frequency distribution
# * Phase-type distribution
# * Probability mass function
# * Distribution of the product of two random variables
# * Ratio distribution
# * Singular distribution
# * Super-Poissonian distribution
# * Taleb distribution
# * Truncated distribution
# * Tsallis distribution
# * Univariate distribution
# * Utilization distribution
# * 2-EPT probability density function
# * Wrapped distribution

# %% [markdown]
# #### ⚓ Complex distributions (3 P)

# %% [markdown]
# #### ⚓ Compound probability distributions (22 P)

# %% [markdown]
# #### ⚓ Conjugate prior distributions (21 P)

# %% [markdown]
# #### [⚓](https://en.wikipedia.org/wiki/Category:Continuous_distributions) Continuous distributions (3 C, 177 P)

# %% [markdown]
# * Arcsine distribution
# * ARGUS distribution
# * Asymmetric Laplace distribution
# * Balding–Nichols model
# * Bates distribution
# * Behrens–Fisher distribution
# * Benini distribution
# * Benktander type I distribution
# * Benktander type II distribution
# * Beta distribution
# * Beta prime distribution
# * Beta rectangular distribution
# * Bingham distribution
# * Birnbaum–Saunders distribution
# * Bivariate von Mises distribution
# * Box–Cox distribution
# * Burr distribution
# * Cantor distribution
# * Cauchy distribution
# * Champernowne distribution
# * Chernoff's distribution
# * Chi distribution
# * Circular uniform distribution
# * Complex inverse Wishart distribution
# * Complex normal distribution
# * Complex Wishart distribution
# * Continuous Bernoulli distribution
# * Crystal Ball function
# * Dagum distribution
# * Davis distribution
# * Dirichlet distribution
# * Double exponential distribution
# * Erlang distribution
# * Exponential distribution
# * Exponential family
# * Exponential-logarithmic distribution
# * Exponentially modified Gaussian distribution
# * Exponentiated Weibull distribution
# * F-distribution
# * Fisher's z-distribution
# * Flory–Schulz distribution
# * Folded normal distribution
# * Folded-t and half-t distributions
# * Fréchet distribution
# * Gamma distribution
# * Gamma/Gompertz distribution
# * Gaussian q-distribution
# * Generalised hyperbolic distribution
# * Generalized beta distribution
# * Generalized chi-squared distribution
# * Generalized Dirichlet distribution
# * Generalized extreme value distribution
# * Generalized gamma distribution
# * Generalized integer gamma distribution
# * Generalized inverse Gaussian distribution
# * Generalized logistic distribution
# * Generalized multivariate log-gamma distribution
# * Generalized normal distribution
# * Generalized Pareto distribution
# * Geometric stable distribution
# * Gompertz distribution
# * Grouped Dirichlet distribution
# * [**Gumbel distribution**](https://en.wikipedia.org/wiki/Gumbel_distribution) ([*Loi de Gumbel*](https://fr.wikipedia.org/wiki/Loi_de_Gumbel))
# * Half-logistic distribution
# * Half-normal distribution
# * Harmonic distribution
# * Holtsmark distribution
# * Hotelling's T-squared distribution
# * Hubbert curve
# * Hyper-Erlang distribution
# * Hyperbolic distribution
# * Hyperbolic secant distribution
# * Hyperexponential distribution
# * Hypoexponential distribution
# * Inverse Gaussian distribution
# * Inverse matrix gamma distribution
# * Inverse-chi-squared distribution
# * Inverse-gamma distribution
# * Inverse-Wishart distribution
# * Inverted bell curve
# * Inverted Dirichlet distribution
# * Irwin–Hall distribution
# * Johnson's SU-distribution
# * K-distribution
# * Kent distribution
# * Kumaraswamy distribution
# * Landau distribution
# * Laplace distribution
# * Lévy distribution
# * Lewandowski-Kurowicka-Joe distribution
# * Linnik distribution
# * Log-Cauchy distribution
# * Log-Laplace distribution
# * Log-logistic distribution
# * Log-normal distribution
# * Log-t distribution
# * Logistic distribution
# * Logit-normal distribution
# * Lomax distribution
# * Marshall–Olkin exponential distribution
# * Matrix gamma distribution
# * Matrix normal distribution
# * Matrix-exponential distribution
# * Maximum entropy probability distribution
# * Maxwell–Boltzmann distribution
# * McCullagh's parametrization of the Cauchy distributions
# * Metalog distribution
# * Mittag-Leffler distribution
# * Moffat distribution
# * Multimodal distribution
# * Multivariate normal distribution
# * Multivariate t-distribution
# * Nakagami distribution
# * Noncentral beta distribution
# * Noncentral chi distribution
# * Noncentral chi-squared distribution
# * Noncentral F-distribution
# * Noncentral t-distribution
# * Normal distribution
# * Normal variance-mean mixture
# * Normal-exponential-gamma distribution
# * Normal-inverse Gaussian distribution
# * Normal-inverse-gamma distribution
# * Pareto distribution
# * Pearson distribution
# * PERT distribution
# * Phase-type distribution
# * Poly-Weibull distribution
# * Polynomial Wigner–Ville distribution
# * Q-exponential distribution
# * Q-Gaussian distribution
# * Q-Weibull distribution
# * Quantile-parameterized distribution
# * Raised cosine distribution
# * Rayleigh distribution
# * Rayleigh mixture distribution
# * Reciprocal distribution
# * Relativistic Breit–Wigner distribution
# * Rice distribution
# * Scaled inverse chi-squared distribution
# * Seneca effect
# * Shifted Gompertz distribution
# * Shifted log-logistic distribution
# * Skew normal distribution
# * Skewed generalized t distribution
# * Slash distribution
# * Split normal distribution
# * Stable count distribution
# * Stable distribution
# * Student's t-distribution
# * Studentized range distribution
# * Sub-Gaussian distribution
# * Tracy–Widom distribution
# * Trapezoidal distribution
# * Triangular distribution
# * Truncated normal distribution
# * Tukey lambda distribution
# * Tweedie distribution
# * Type-2 Gumbel distribution
# * U-quadratic distribution
# * Continuous uniform distribution
# * Variance-gamma distribution
# * Voigt profile
# * Von Mises distribution
# * Von Mises–Fisher distribution
# * Wakeby distribution
# * Weibull distribution
# * Wigner quasiprobability distribution
# * Wigner semicircle distribution
# * Wilks's lambda distribution
# * Wishart distribution
# * Wrapped asymmetric Laplace distribution
# * Wrapped Cauchy distribution
# * Wrapped exponential distribution
# * Wrapped Lévy distribution
# * Wrapped normal distribution
# * Zero degrees of freedom

# %% [markdown]
# ##### [⚓](https://en.wikipedia.org/wiki/Category:Exponential_family_distributions) Exponential family distributions (2 C, 37 P)

# %% [markdown]
# ##### [⚓](https://en.wikipedia.org/wiki/Category:Normal_distribution)__ Normal distribution (2 C, 53 P)

# %% [markdown]
# * [**Generalized normal distribution**](https://en.wikipedia.org/wiki/Generalized_normal_distribution) ([*Loi normale généralisée*](https://fr.wikipedia.org/wiki/Loi_normale_géralisée))
# * [**Normal distribution**](https://en.wikipedia.org/wiki/Normal_distribution) ([*Loi normale*](https://fr.wikipedia.org/wiki/Loi_normale))
# * 68–95–99.7 rule
# * 97.5th percentile point
# * Anscombe transform
# * Chi distribution
# * Chi-squared distribution
# * Elliptical distribution
# * Erdős–Kac theorem
# * Fieller's theorem
# * Folded normal distribution
# * Galton board
# * Gaussian noise
# * Gaussian process
# * Graphical lasso
# * Half-normal distribution
# * Isserlis' theorem
# * James–Stein estimator
# * Kac–Bernstein theorem
# * Kurtosis risk
# * Log-normal distribution
# * Markov chain central limit theorem
# * Maxwell–Boltzmann distribution
# * Modified lognormal power-law distribution
# * Multivariate Behrens–Fisher problem
# * Multivariate normal distribution
# * Normal probability plot
# * Normal-gamma distribution
# * Normal-inverse-gamma distribution
# * Normal-inverse-Wishart distribution
# * Normal-Wishart distribution
# * Normally distributed and uncorrelated does not imply independent
# * Owen's T function
# * Power transform
# * Pregaussian class
# * Probit
# * Q-function
# * Rankit
# * Rectified Gaussian distribution
# * [**Skew normal distribution**](https://en.wikipedia.org/wiki/Skew_normal_distribution) ([*Loi normale asymétrique*](https://fr.wikipedia.org/wiki/Loi_normale_asymétrique))
# * Skewed generalized t distribution
# * Slash distribution
# * Split normal distribution
# * Standard normal deviate
# * Standard normal table
# * Student's t-distribution
# * Sum of normally distributed random variables
# * T-statistic
# * Truncated normal distribution
# * Whittle likelihood
# * Wrapped normal distribution
# * Z-test
# * Zero degrees of freedom

# %% [markdown]
# ##### [⚓](https://en.wikipedia.org/wiki/Category:Central_limit_theorem)____ Central limit theorem (10 P)

# %% [markdown]
# * [**Central limit theorem (CLT)**](https://en.wikipedia.org/wiki/Central_limit_theorem)
# * [**Central limit theorem for directional statistics**](https://en.wikipedia.org/wiki/Central_limit_theorem_for_directional_statistics)
# * [**Markov chain central limit theorem**](https://en.wikipedia.org/wiki/Markov_chain_central_limit_theorem)
# * [**Berry–Esseen theorem**](https://en.wikipedia.org/wiki/Berry–Esseen_theorem)
# * [**De Moivre–Laplace theorem**](https://en.wikipedia.org/wiki/De_Moivre–Laplace_theorem)
# * [**Lindeberg's condition**](https://en.wikipedia.org/wiki/Lindeberg's_condition)
# * [*Lyapunov's central limit theorem*](https://en.wikipedia.org/wiki/Central_limit_theorem#Lyapunov_CLT)
# * [**Martingale central limit theorem**](https://en.wikipedia.org/wiki/Martingale_central_limit_theorem)
# * [Illustration of the central limit theorem](https://en.wikipedia.org/wiki/Illustration_of_the_central_limit_theorem)
# * [Galton board](https://en.wikipedia.org/wiki/Galton_board)

# %% [markdown]
# ##### [⚓](https://en.wikipedia.org/wiki/Category:Normality_tests)____ Normality tests (11 P)

# %% [markdown]
# * [**Normality test**](https://en.wikipedia.org/wiki/Normality_test)
# * [**Anderson–Darling test**](https://en.wikipedia.org/wiki/Anderson–Darling_test)
# * [**Cramér–von Mises criterion**](https://en.wikipedia.org/wiki/Cramér–von_Mises_criterion)
# * [**D'Agostino's *K*-squared test**](https://en.wikipedia.org/wiki/D'Agostino's_K-squared_test)
# * [**Jarque–Bera test**](https://en.wikipedia.org/wiki/Jarque–Bera_test)
# * [**Kolmogorov–Smirnov test**](https://en.wikipedia.org/wiki/Kolmogorov–Smirnov_test)
# * [**Lilliefors test**](https://en.wikipedia.org/wiki/Lilliefors_test)
# * [**Normal probability plot**](https://en.wikipedia.org/wiki/Normal_probability_plot)
# * [**Pearson's chi-squared test**](https://en.wikipedia.org/wiki/Pearson's_chi-squared_test)
# * [**Shapiro–Wilk test**](https://en.wikipedia.org/wiki/Shapiro–Wilk_test)
# * [**Shapiro–Francia test**](https://en.wikipedia.org/wiki/Shapiro–Francia_test)

# %% [markdown]
# ##### [⚓](https://en.wikipedia.org/wiki/Category:Poisson_distribution)__ Poisson distribution (1 C, 13 P)

# %% [markdown]
# * [**Poisson distribution**](https://en.wikipedia.org/wiki/Poisson_distribution) ([*Loi de Poisson*](https://fr.wikipedia.org/wiki/Loi_de_Poisson))
# * Anscombe transform
# * Compound Poisson distribution
# * Conway–Maxwell–Poisson distribution
# * Endogeneity with an exponential regression function
# * Geometric Poisson distribution
# * Poisson regression
# * Poisson wavelet
# * Poisson-type random measure
# * Pooled QMLE for Poisson Models
# * Robbins lemma
# * Skellam distribution
# * Zero-truncated Poisson distribution

# %% [markdown]
# ##### [⚓](https://en.wikipedia.org/wiki/Category:Poisson_point_processes)____ Poisson point processes (17 P)

# %% [markdown]
# ##### [⚓](https://en.wikipedia.org/wiki/Category:Geometric_stable_distributions) Geometric stable distributions (6 P)

# %% [markdown]
# ##### [⚓](https://en.wikipedia.org/wiki/Category:Multivariate_continuous_distributions) Multivariate continuous distributions (30 P)

# %% [markdown]
# * Bivariate von Mises distribution
# * Complex inverse Wishart distribution
# * Complex normal distribution
# * Complex Wishart distribution
# * Dirichlet distribution
# * Generalized Dirichlet distribution
# * Generalized multivariate log-gamma distribution
# * Grouped Dirichlet distribution
# * Inverse matrix gamma distribution
# * Inverse-Wishart distribution
# * Inverted Dirichlet distribution
# * Lewandowski-Kurowicka-Joe distribution
# * Matrix gamma distribution
# * Matrix normal distribution
# * Matrix t-distribution
# * Matrix variate beta distribution
# * Mehler kernel
# * Multivariate Behrens–Fisher problem
# * Multivariate Laplace distribution
# * Multivariate logistic distribution
# * Multivariate normal distribution
# * Multivariate t-distribution
# * Multivariate Pareto distribution
# * Multivariate stable distribution
# * Normal-gamma distribution
# * Normal-inverse-gamma distribution
# * Normal-inverse-Wishart distribution
# * Normal-Wishart distribution
# * Von Mises–Fisher distribution
# * Wishart distribution

# %% [markdown]
# #### ⚓ Discrete distributions (2 C, 50 P)
#
# * ⚓ Multivariate discrete distributions (5 P)
# * ⚓ Poisson distribution (1 C, 13 P)
# * * ⚓ Poisson point processes (17 P)

# %% [markdown]
# * (a,b,0) class of distributions
# * Bernoulli distribution
# * Bernoulli trial
# * Beta negative binomial distribution
# * Beta-binomial distribution
# * Binomial distribution
# * Borel distribution
# * Categorical distribution
# * Compound Poisson distribution
# * Conway–Maxwell–binomial distribution
# * [**Conway–Maxwell–Poisson distribution (CMP)**](https://en.wikipedia.org/wiki/Conwayl–Maxwell–Poisson_distribution) ([Loi de Conway-Maxwell-Poisson (CMP)](https://fr.wikipedia.org/wiki/Loi_de_Conway-Maxwell-Poisson))
# * Degenerate distribution
# * Delaporte distribution
# * Dirichlet-multinomial distribution
# * Discrete phase-type distribution
# * Discrete uniform distribution
# * Discrete Weibull distribution
# * Discrete-stable distribution
# * Displaced Poisson distribution
# * Dyadic distribution
# * Ewens's sampling formula
# * Exponential family
# * Extended negative binomial distribution
# * Fisher's noncentral hypergeometric distribution
# * Gauss–Kuzmin distribution
# * Geometric distribution
# * German tank problem
# * Hermite distribution
# * Hypergeometric distribution
# * Kirkwood approximation
# * Logarithmic distribution
# * Maximum entropy probability distribution
# * Mixed Poisson distribution
# * Multinomial distribution
# * Negative binomial distribution
# * Negative hypergeometric distribution
# * Noncentral hypergeometric distributions
# * Parabolic fractal distribution
# * Poisson binomial distribution
# * Rademacher distribution
# * Rencontres numbers
# * Skellam distribution
# * Soliton distribution
# * Van Houtum distribution
# * Wallenius' noncentral hypergeometric distribution
# * Yule–Simon distribution
# * Zero-truncated Poisson distribution
# * Zeta distribution
# * Zipf–Mandelbrot law
# * Zipf's law

# %% [markdown]
# #### ⚓ Infinitely divisible probability distributions (1 C, 15 P)
# * ⚓ Stable distributions (1 C, 8 P)
# * * ⚓ Geometric stable distributions (6 P)

# %% [markdown]
# #### ⚓ Location-scale family probability distributions (15 P)

# %% [markdown]
# #### ⚓ Noncentral distributions (5 P)

# %% [markdown]
# #### ⚓ Probability distributions with non-finite variance (29 P)

# %% [markdown]
# #### [⚓](https://en.wikipedia.org/wiki/Category:Stable_distributions) Stable distributions (1 C, 8 P)

# %% [markdown]
# * Stable count distribution
# * Stable distribution
# * Cauchy distribution
# * Holtsmark distribution
# * Landau distribution
# * Lévy distribution
# * Multivariate normal distribution
# * Normal distribution

# %% [markdown]
# ##### [⚓](https://en.wikipedia.org/wiki/Category:Geometric_stable_distributions) Geometric stable distributions (6 P)

# %% [markdown]
# * Geometric stable distribution
# * Asymmetric Laplace distribution
# * Laplace distribution
# * Linnik distribution
# * Mittag-Leffler distribution
# * Multivariate Laplace distribution

# %% [markdown]
# #### ⚓ Systems of probability distributions (8 P)
