# %% [markdown]
# # **Brazil**

# %% [markdown]
# ## Brazil states

# %%
from scraping import get_brazil_states

display(get_brazil_states())
# Out:
#           Flag and name Code         Capital    Largest city  Area(km2)[20]  \
# 0                  Acre   AC      Rio Branco      Rio Branco         164123
# 1               Alagoas   AL          Maceió          Maceió          27779
# 2                 Amapá   AP          Macapá          Macapá         142829
# 3              Amazonas   AM          Manaus          Manaus        1559159
# 4                 Bahia   BA        Salvador        Salvador         564733
# 5                 Ceará   CE       Fortaleza       Fortaleza         148921
# 6      Distrito Federal   DF        Brasília        Brasília           5780
# 7        Espírito Santo   ES         Vitória           Serra          46095
# 8                 Goiás   GO         Goiânia         Goiânia         340112
# 9              Maranhão   MA        São Luís        São Luís         331937
# 10          Mato Grosso   MT          Cuiabá          Cuiabá         903366
# ...

# %% [markdown]
# ## Brazil municipalities

# %%
from scraping import scrap_brazil_municipalities

display(scrap_brazil_municipalities())
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# c:\Users\franc\Projects\pepper_automatic_product_classification_engine\notebooks\scraping.ipynb Cell 4 in <cell line: 3>()
#
#       <a href='vscode-notebook-cell:/c%3A/Users/franc/Projects/pepper_automatic_product_classification_engine/notebooks/scraping.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> from scraping import scrap_brazil_municipalities
#
# ----> <a href='vscode-notebook-cell:/c%3A/Users/franc/Projects/pepper_automatic_product_classification_engine/notebooks/scraping.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> display(scrap_brazil_municipalities())
#
#
#
# File c:\Users\franc\Projects\pepper_automatic_product_classification_engine\notebooks\scraping.py:57, in scrap_brazil_municipalities()
#
#      54     data_list += [data]
#
#      56 # merge into a unique dataframe
#
# ---> 57 all = pd.concat(data_list, axis=0, ignore_index=True)
# ...
